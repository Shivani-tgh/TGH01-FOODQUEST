# %%
# %sql
CREATE TABLE fq_dev_catalog.silver.dim_company
(
    sys_id STRING NOT NULL,
    company_id STRING NOT NULL,
    company_name STRING NOT NULL,
    is_active BOOLEAN NOT NULL,
    source_system STRING NOT NULL,
    CONSTRAINT company_id_pk PRIMARY KEY (company_id)
)
USING DELTA
TBLPROPERTIES (
    delta.enableChangeDataFeed = true
);

# %%
# %sql
drop table fq_dev_catalog.silver.dim_company

# %%
# %sql
INSERT INTO fq_dev_catalog.silver.dim_company
(sys_id, company_id, company_name, is_active, source_system)

SELECT uuid(), 'SQ', 'ServQuest', TRUE, 'FQ'
UNION ALL
SELECT uuid(), 'AI', 'Advance Investment', TRUE, 'FQ';

# %%
# %sql
select * from fq_dev_catalog.silver.dim_company

# %%
cdf_df = spark.read.format("delta") \
    .option("readChangeData", "true") \
    .option("startingVersion", 0) \
    .table("fq_dev_catalog.silver.dim_company")

cdf_df.display(truncate=False)

# %%
# %sql
describe extended fq_dev_catalog.silver.dim_company

# %%
# %sql
describe history fq_dev_catalog.silver.dim_company

# %%
# %sql
ALTER TABLE fq_dev_catalog.silver.dim_company SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
